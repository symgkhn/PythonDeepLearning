# %% [markdown]
# <a href="https://colab.research.google.com/github/symgkhn/PythonDeepLearning/blob/main/Vekt%C3%B6rler_Matrisler_Tens%C3%B6rler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VEKTÖRLER
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
x = np.array(7)
x
# Out:
# array(7)

# %%
x.ndim
# Out:
# 0

# %%
x = np.array([7, 14, 21])
x
# Out:
# array([ 7, 14, 21])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# # MATRİS
# ![image.png](data:image/png;base64,...)

# %%
x = np.array([[7,14,21],
             [7,14,21],
             [7,14,21]])
x
# Out:
# array([[ 7, 14, 21],
#        [ 7, 14, 21],
#        [ 7, 14, 21]])

# %%
x.ndim
# Out:
# 2

# %% [markdown]
# # TENSORLER
# ![image.png](data:image/png;base64,...)

# %%
x = np.array([[[7, 14,21], [7, 14,21]], 
             [[87, 89, 93], [87,89,93]],
              [[10, 4, 7],[10, 4, 7]]])
x
# Out:
# array([[[ 7, 14, 21],
#         [ 7, 14, 21]],
#
#        [[87, 89, 93],
#         [87, 89, 93]],
#
#        [[10,  4,  7],
#         [10,  4,  7]]])

# %%
x.ndim
# Out:
# 3

# %% [markdown]
# Görüntü Verisinden örnek gösterim

# %%
from keras.datasets import mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
print(train_images.ndim)
# Out:
# 3

# %%
print(train_images.shape)
# Out:
# (60000, 28, 28)

# %%
print(test_images.ndim)
# Out:
# 3

# %%
print(test_images.shape)
# Out:
# (10000, 28, 28)

# %%
print(train_images.dtype)
# Out:
# uint8

# %%
digit = train_images[10]

# %%
import matplotlib.pyplot as plt
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
dizinim = train_images[7:77]

print(dizinim.shape)
# Out:
# (70, 28, 28)

# %%
dizinim = train_images[7:77, :, :]
dizinim.shape
# Out:
# (70, 28, 28)

# %%
dizinim = train_images[7:77, 0:14, 0:14]
dizinim.shape
# Out:
# (70, 14, 14)

# %% [markdown]
# ## İşlemler
#
#   . Eleman Temelli
#
# Bu işlemler tensörün her elemanına ayrı ayrı uygulanır.

# %%
def naive_add(x, y):
  assert len(x.shape) == 2 #x ve y 2 boyutlu numpy tensörü
  assert x.shape == y.shape

  x=x.copy()

  for i in range(x.shape[0]):
    for j in range(x.shape[1]):
      x[i,j] += y[i,j]
  return x

# %%
x = np.array([[7,14,21],
             [7,14,21],
             [7,14,21]])
y = np.array([[2,12,20],
             [7,3,2],
             [7,4,1]])

z = naive_add(x,y)
z
# Out:
# array([[ 9, 26, 41],
#        [14, 17, 23],
#        [14, 18, 22]])

# %%
import numpy as np

x = np.array([[7,14,21],
             [7,14,21],
             [7,14,21]])
y = np.array([[2,12,20],
             [7,3,2],
             [7,4,1]])

z = x+y
z
# Out:
# array([[ 9, 26, 41],
#        [14, 17, 23],
#        [14, 18, 22]])

# %%
def naive_relu(x):
  assert len(x.shape) == 2
  
  x = x.copy()

  for i in range(x.shape[0]):
    for j in range(x.shape[1]):
      x[i,j]=max(x[i,j],0)
  return x

# %%
x = np.array([[-7,14,21],
             [7,-14,21],
             [7,14,-21]])
y = np.array([[2,12,20],
             [7,3,2],
             [7,4,1]])

z=naive_relu(x)
z
# Out:
# array([[ 0, 14, 21],
#        [ 7,  0, 21],
#        [ 7, 14,  0]])

# %%
import numpy as np

z=np.maximum(x,0)
z
# Out:
# array([[ 0, 14, 21],
#        [ 7,  0, 21],
#        [ 7, 14,  0]])

# %% [markdown]
# ###  .Yayma Operasyonu

# %%
def naive_add_matrix_and_vector(x,y):
  assert len(x.shape) == 2
  assert len(y.shape) ==1
  assert x.shape[1] == y.shape[0]

  x=x.copy()

  for i in range(x.shape[0]):
    for j in range(x.shape[1]):
      x[i,j] += y[j]
  return x

# %%
x = np.array([[7,14,21],
             [7,14,21],
             [7,14,21]])
y = np.array([1,2,3])

z = naive_add_matrix_and_vector(x,y)
z
# Out:
# array([[ 8, 16, 24],
#        [ 8, 16, 24],
#        [ 8, 16, 24]])

# %%
x = np.random.random((64,3,32,10))
y = np.random.random((32,10))

z=np.maximum(x,y)
z.shape
# Out:
# (64, 3, 32, 10)

# %% [markdown]
# ## İç Çarpım İşlemi

# %%
import numpy as np

x = np.array([[1,2],
              [1,2]])
y = np.array([[1,2],
              [1,2]])

z = np.dot(x,y)
z
# Out:
# array([[3, 6],
#        [3, 6]])

# %% [markdown]
# ## Kanal/Şekil Değiştirme

# %%
x = np.array([[0.,1.],
              [2.,3.],
              [4.,5.]])

x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = np.zeros((100, 10))
x = np.transpose(x)
print(x.shape)
# Out:
# (10, 100)
